# %%
# 행렬에도 각각 고유의 특성과 용도를 가진 것들이 존재
# 1) 복잡한 계산을 단순화하거나 2) 실제 문제에서 빈도 높은 구조를 표현하거나
# 3) DL/ML에서 핵심 역할을 함
# 단위행렬 - 변화 없음, 대각행렬 - 독립적인 변화, 대칭행렬 - 균형잡힌 관계

# %%
# 영행렬 - 모든 원소가 0인 행렬
# 변화 없음, 시스템의 정지 상태, 딥러닝에서 가중치가 모두 0인 경우

# 단위행렬 - 대각선 원소들은 모두 1, 나머지는 0인 정사각행렬
# 일반 숫자에서 1이 곱셈의 항등원이듯, 행렬에서는 단위행렬이 곱셈의 항등원
# 역행렬의 정의에 필수: 역행렬은 원래 행렬과 곱해서 단위행렬이 되는 행렬

# 대각행렬 - 대각선 외의 모든 원소가 0인 정사각행렬
# 1) 곱셈, 거듭제곱, 역행렬 계산이 매우 쉬움 2) 대각선 원소만 저장하면 됨 
# 3) 물리적으로 독립적인 방향의 확대 및 축소를 나타냄
# 대각행렬 곱셈 - 각 성분이 독립적 확대
# 대각행렬 거듭제곱 - 각 성분의 거듭제곱
